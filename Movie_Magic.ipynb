# %%
#Import lIBRARIES
import pandas as pd
import numpy as np
import os as os

# %%
# example making new folder with os

os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# []

# %% [markdown]
# # Basics Data Load & Clean

# %%
##Load Basics set and assign to DF

basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"

basicsDF = pd.read_csv(basics_url, sep='\t', low_memory=False)

basicsDF.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#Assign local file to DF
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory=False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#Basics preprocessing

#Replace "\N" with np.nan
basics.replace({'\\N':np.nan}, inplace=True) 
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
#Eliminate movies that are null for runtimeMinutes
basics[{'runtimeMinutes','genres'}].dropna(inplace=True)
basics.head()
# Out:
# C:\Users\staichn\AppData\Local\Temp\ipykernel_41756\3849636033.py:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   basics[{'runtimeMinutes','genres'}].dropna(inplace=True)
# C:\Users\staichn\AppData\Local\Temp\ipykernel_41756\3849636033.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics[{'runtimeMinutes','genres'}].dropna(inplace=True)
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
#keep only titleType==Movie
movie_filter = basics['titleType']=='movie'
movie_filter.head()

basics[movie_filter].head()
# Out:
#         tconst titleType                 primaryTitle  \
# 498  tt0000502     movie                     Bohemios
# 570  tt0000574     movie  The Story of the Kelly Gang
# 587  tt0000591     movie             The Prodigal Son
# 610  tt0000615     movie           Robbery Under Arms
# 625  tt0000630     movie                       Hamlet
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 498                     Bohemios       0      1905     NaN            100
# 570  The Story of the Kelly Gang       0      1906     NaN             70
# 587            L'enfant prodigue       0      1907     NaN             90
# 610           Robbery Under Arms       0      1907     NaN            NaN
# 625                       Amleto       0      1908     NaN            NaN
#
#                          genres
# 498                         NaN
# 570  Action,Adventure,Biography
# 587                       Drama
# 610                       Drama
# 625                       Drama

# %%
basics['runtimeMinutes'].dropna(inplace=True)
basics.head()
# Out:
# C:\Users\staichn\AppData\Local\Temp\ipykernel_41756\450490218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics['runtimeMinutes'].dropna(inplace=True)
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
#keep startYear 2000-2022
start_filt = basics['startYear'] >= '2000'
start_filt.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: startYear, dtype: bool

# %%
end_filt = basics['startYear']<='2022'
end_filt.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: startYear, dtype: bool

# %%
basics = basics.loc[start_filt & end_filt, :]
basics.head()
# Out:
#           tconst titleType                 primaryTitle  \
# 11636  tt0011801     movie             Tötet nicht mehr
# 13082  tt0013274     movie  Istoriya grazhdanskoy voyny
# 15179  tt0015414     movie       La tierra de los toros
# 33805  tt0034413     short           Youth Gets a Break
# 34805  tt0035423     movie               Kate & Leopold
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 11636             Tötet nicht mehr       0      2019     NaN            NaN
# 13082  Istoriya grazhdanskoy voyny       0      2021     NaN            133
# 15179       La tierra de los toros       0      2000     NaN             60
# 33805           Youth Gets a Break       0      2001     NaN             20
# 34805               Kate & Leopold       0      2001     NaN            118
#
#                        genres
# 11636            Action,Crime
# 13082             Documentary
# 15179                     NaN
# 33805                   Short
# 34805  Comedy,Fantasy,Romance

# %%
#Eliminate movies that include  "Documentary" in genre (see tip below)
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]
basics.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [143], in <cell line: 3>()
#       1 #Eliminate movies that include  "Documentary" in genre (see tip below)
#       2 is_documentary = basics['genres'].str.contains('documentary',case=False)
# ----> 3 basics = basics[~is_documentary]
#       4 basics.head()
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:1522, in NDFrame.__invert__(self)
#    1518 if not self.size:
#    1519     # inv fails with 0 len
#    1520     return self
# -> 1522 new_data = self._mgr.apply(operator.invert)
#    1523 return self._constructor(new_data).__finalize__(self, method="__invert__")
#
# File ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py:302, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     300 try:
#     301     if callable(f):
# --> 302         applied = b.apply(f, **kwargs)
#     303     else:
#     304         applied = getattr(b, f)(**kwargs)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402, in Block.apply(self, func, **kwargs)
#     396 @final
#     397 def apply(self, func, **kwargs) -> list[Block]:
#     398     """
#     399     apply the function to my values; return a block if we are not
#     400     one
#     401     """
# --> 402     result = func(self.values, **kwargs)
#     404     return self._split_op_result(result)
#
# TypeError: bad operand type for unary ~: 'float'

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3766250 entries, 11636 to 8961734
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 287.3+ MB

# %% [markdown]
# # AKAs Data Load & Clean

# %%
##Load AKAs data set and save locally 
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"

akasDF = pd.read_csv(akas_url, sep='\t', low_memory=False)

akasDF.to_csv("Data/title.akas.csv.gz",compression='gzip',index=False)

# %%
#Assign local file to DF
akas = pd.read_csv("Data/title.akas.csv.gz", low_memory=False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
#AKA Preprocessing
akas.replace({'\\N':np.nan}, inplace=True)

# %%
#AKA - keep only US entries. I keep breaking the main df, I'm creating a dummy
#df that I will move back once done.
dfa= akas
dfa.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
#Apply filter to retain only movies in US region
region_filt = dfa['region']=='US'
region_filt.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: region, dtype: bool

# %%
#Check that filtering worked...it did.  ONLY US region films are showing.
dfa[region_filt].head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
dfa = dfa.loc[region_filt, :]
dfa.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
dfa['region'].value_counts()
# Out:
# US    1325004
# Name: region, dtype: int64

# %%
#Transfer dummy set back to actual df
akas = dfa
akas.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
#Save new cleansed df to local csv file from earlier 
akas.to_csv("Data/title.akas.csv.gz",compression='gzip',index=False)

# %%
#Display df info as requested
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1325004 entries, 5 to 32156132
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1325004 non-null  object
#  1   ordering         1325004 non-null  int64
#  2   title            1325004 non-null  object
#  3   region           1325004 non-null  object
#  4   language         3549 non-null     object
#  5   types            1025738 non-null  object
#  6   attributes       44079 non-null    object
#  7   isOriginalTitle  1323629 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 91.0+ MB

# %% [markdown]
# # Ratings Data Load & Clean

# %%
##Load Ratings data set and assign to DF
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"

ratingsDF = pd.read_csv(ratings_url, sep='\t', low_memory=False)

ratingsDF.to_csv("Data/title.ratings.csv.gz",compression='gzip',index=False)

# %%
#Assign local file to DF
ratings = pd.read_csv("Data/title.ratings.csv.gz", low_memory=False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1883
# 1  tt0000002            5.9       250
# 2  tt0000003            6.5      1667
# 3  tt0000004            5.8       163
# 4  tt0000005            6.2      2490

# %%
#RATINGS Preprocessing
ratings.replace({'\\N':np.nan})
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1883
# 1        tt0000002            5.9       250
# 2        tt0000003            6.5      1667
# 3        tt0000004            5.8       163
# 4        tt0000005            6.2      2490
# ...            ...            ...       ...
# 1249571  tt9916690            6.5         6
# 1249572  tt9916720            5.3       219
# 1249573  tt9916730            8.4         6
# 1249574  tt9916766            6.8        20
# 1249575  tt9916778            7.2        35
#
# [1249576 rows x 3 columns]

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249576 entries, 0 to 1249575
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1249576 non-null  object
#  1   averageRating  1249576 non-null  float64
#  2   numVotes       1249576 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.6+ MB

# %%
ratings.to_csv("Data/title.ratings.csv.gz",compression='gzip',index=False)

# %% [markdown]
# # Filtering Dataframes Upon One Another

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 8961731     True
# 8961732     True
# 8961733     True
# 8961734     True
# 8961735    False
# Name: tconst, Length: 8961736, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst  titleType            primaryTitle           originalTitle  \
# 0        tt0000001      short              Carmencita              Carmencita
# 1        tt0000002      short  Le clown et ses chiens  Le clown et ses chiens
# 2        tt0000003      short          Pauvre Pierrot          Pauvre Pierrot
# 3        tt0000004      short             Un bon bock             Un bon bock
# 4        tt0000005      short        Blacksmith Scene        Blacksmith Scene
# ...            ...        ...                     ...                     ...
# 8961730  tt9916846  tvEpisode           Episode #3.18           Episode #3.18
# 8961731  tt9916848  tvEpisode           Episode #3.17           Episode #3.17
# 8961732  tt9916850  tvEpisode           Episode #3.19           Episode #3.19
# 8961733  tt9916852  tvEpisode           Episode #3.20           Episode #3.20
# 8961734  tt9916856      short                The Wind                The Wind
#
#         isAdult startYear endYear runtimeMinutes                    genres
# 0             0      1894     NaN              1         Documentary,Short
# 1             0      1892     NaN              5           Animation,Short
# 2             0      1892     NaN              4  Animation,Comedy,Romance
# 3             0      1892     NaN             12           Animation,Short
# 4             0      1893     NaN              1              Comedy,Short
# ...         ...       ...     ...            ...                       ...
# 8961730       0      2010     NaN            NaN       Action,Drama,Family
# 8961731       0      2010     NaN            NaN       Action,Drama,Family
# 8961732       0      2010     NaN            NaN       Action,Drama,Family
# 8961733       0      2010     NaN            NaN       Action,Drama,Family
# 8961734       0      2015     NaN             27                     Short
#
# [6335160 rows x 9 columns]
