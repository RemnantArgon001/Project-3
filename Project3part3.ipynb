# %% [markdown]
# ## Required Transformation steps:
#     - Convert the single string of genres from title basics into 2 new tables

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy.types import *
from sqlalchemy_utils import create_database, database_exists

# %%
#load file and disply rows
df_title_basics = pd.read_csv('Data/Final_basics.csv.gz')
df_title_ratings = pd.read_csv('Data/title.ratings.csv.gz')
display(df_title_basics.head(), df_title_ratings.head())
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0093119     movie                                Grizzly II: Revenge
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                   Grizzly II: The Predator        0       2020      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74   Horror,Music,Thriller
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1888
# 1  tt0000002            5.9       251
# 2  tt0000003            6.5      1680
# 3  tt0000004            5.8       164
# 4  tt0000005            6.2      2499

# %%
df_title_basics['genres_split'] = df_title_basics['genres'].str.split(',')
df_title_basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0093119     movie                                Grizzly II: Revenge
# ...          ...       ...                                                ...
# 81411  tt9914942     movie                             Life Without Sara Amat
# 81412  tt9915872     movie                               The Last White Witch
# 81413  tt9916170     movie                                      The Rehearsal
# 81414  tt9916190     movie                                          Safeguard
# 81415  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# 3                              The Naked Monster        0       2005      NaN
# 4                       Grizzly II: The Predator        0       2020      NaN
# ...                                          ...      ...        ...      ...
# 81411                 La vida sense la Sara Amat        0       2019      NaN
# 81412                  My Girlfriend is a Wizard        0       2019      NaN
# 81413                                   O Ensaio        0       2019      NaN
# 81414                                  Safeguard        0       2020      NaN
# 81415                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                  74      Horror,Music,Thriller
# ...               ...                        ...
# 81411              74                      Drama
# 81412              97       Comedy,Drama,Fantasy
# 81413              51                      Drama
# 81414              90  Action,Adventure,Thriller
# 81415              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4          [Horror, Music, Thriller]
# ...                              ...
# 81411                        [Drama]
# 81412       [Comedy, Drama, Fantasy]
# 81413                        [Drama]
# 81414  [Action, Adventure, Thriller]
# 81415               [Drama, History]
#
# [81416 rows x 10 columns]

# %%
exploded_genres = df_title_basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 81414  tt9916190     movie                                          Safeguard
# 81414  tt9916190     movie                                          Safeguard
# 81414  tt9916190     movie                                          Safeguard
# 81415  tt9916362     movie                                              Coven
# 81415  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# ...                                          ...      ...        ...      ...
# 81414                                  Safeguard        0       2020      NaN
# 81414                                  Safeguard        0       2020      NaN
# 81414                                  Safeguard        0       2020      NaN
# 81415                                   Akelarre        0       2020      NaN
# 81415                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 81414              90  Action,Adventure,Thriller       Action
# 81414              90  Action,Adventure,Thriller    Adventure
# 81414              90  Action,Adventure,Thriller     Thriller
# 81415              92              Drama,History        Drama
# 81415              92              Drama,History      History
#
# [151971 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)
title_genres = title_genres.drop(columns='genres_split')
title_genres.head()
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 0  tt0035423         9
# 0  tt0035423        18
# 1  tt0062336         7
# 2  tt0069049         7

# %%
genre_lookup = pd.DataFrame({'genre_name': genre_map.keys(),
                            'genre_id': genre_map.values()})
genre_lookup.head()
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
with open('/Users/tanma/.secret/mysql.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['user', 'password'])

# %%
connection_str = f"mysql+pymysql://{login['user']}:{login['password']}@localhost/Movies"
engine = create_engine(connection_str)

# %%
if database_exists(connection_str) == False: create_database(connection_str)
else: print('The database already exists.')

# %%
df_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81416 entries, 0 to 81415
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81416 non-null  object
#  1   titleType       81416 non-null  object
#  2   primaryTitle    81416 non-null  object
#  3   originalTitle   81416 non-null  object
#  4   isAdult         81416 non-null  int64
#  5   startYear       81416 non-null  int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  81416 non-null  int64
#  8   genres          81416 non-null  object
#  9   genres_split    81416 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 6.2+ MB

# %%
df_title_basics = df_title_basics.drop(columns = ['titleType', 'originalTitle',
                                                  'isAdult', 'endYear', 'genres', 'genres_split'])
df_title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81416 entries, 0 to 81415
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81416 non-null  object
#  1   primaryTitle    81416 non-null  object
#  2   startYear       81416 non-null  int64
#  3   runtimeMinutes  81416 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 2.5+ MB

# %%
#calculate max string lengths
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = df_title_basics['tconst'].fillna('').map(len).max()
title_len = df_title_basics['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
#save the sql with dtype and index=False
df_title_basics.to_sql('title_basics', engine, dtype=df_schema,
                      if_exists = 'replace', index=False)

# %%
#update the table and column with sqlalchemy
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %% [markdown]
# ## df_title_ratings

# %%
df_title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254542 entries, 0 to 1254541
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1254542 non-null  object
#  1   averageRating  1254542 non-null  float64
#  2   numVotes       1254542 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.7+ MB

# %%
## Calculate max string lengths for object columns
key_len = df_title_ratings['tconst'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    'averageRating': Float(),
    'numVotes': Integer()}

# %%
#save to sql with dtype and index=False
df_title_ratings.to_sql('title_ratings', engine, dtype=df_schema,
                      if_exists = 'replace', index=False)

# %%
# Use the sqlalchemy engine to update the table and set tconst as the primary key
engine.execute('ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`);')

# %% [markdown]
# ## title_genres

# %%
title_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151971 entries, 0 to 81415
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   tconst    151971 non-null  object
#  1   genre_id  151971 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.5+ MB

# %%
## Calculate max string lengths for object columns
key_len = title_genres['tconst'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    'genre_id': Integer()}

# %%
#save to sql with dtype and index=false
title_genres.to_sql('title_genres', engine, dtype=df_schema, 
                   if_exists = 'replace', index=False)

# %% [markdown]
# ## genres

# %%
genre_lookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   genre_name  26 non-null     object
#  1   genre_id    26 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 544.0+ bytes

# %%
## Calculate max string lengths for object columns
key_len = genre_lookup['genre_name'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "genre_name": String(key_len+1), 
    'genre_id': Integer()}

# %%
#save to sql with dtype and index=false
genre_lookup.to_sql('genres', engine, dtype=df_schema,
                   if_exists = 'replace', index=False)

# %%
# Use the sqlalchemy engine to update the table and set genre_id as the primary key
engine.execute('ALTER TABLE genres ADD PRIMARY KEY (`genre_id`);')

# %%
tmdb_df = pd.read_csv('Data/tmdb_results_combined.csv.gz')
tmdb_df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 1  tt0113092    0.0                               NaN                   NaN
# 2  tt0116391    0.0                               NaN                   NaN
# 3  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
# 4  tt0118852    0.0                               NaN                   NaN
#
#        budget                                             genres  \
# 0  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 2         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 4         0.0                      [{'id': 18, 'name': 'Drama'}]
#
#                                homepage        id original_language  \
# 0                                   NaN   62127.0                en
# 1                                   NaN  110977.0                en
# 2                                   NaN  442869.0                hi
# 3  http://www.wkw-inthemoodforlove.com/     843.0                cn
# 4                                   NaN   49511.0                en
#
#     original_title  ...     revenue  runtime  \
# 0  The Fantasticks  ...         0.0     86.0
# 1    For the Cause  ...         0.0    100.0
# 2             Gang  ...         0.0    152.0
# 3             花樣年華  ...  12854953.0     99.0
# 4   Chinese Coffee  ...         0.0     99.0
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 3  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                 title  \
# 0      Try to remember the first time magic happened       The Fantasticks
# 1       The ultimate showdown on a forbidden planet.         For the Cause
# 2                                                NaN                  Gang
# 3  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
# 4  There's a fine line between friendship and bet...        Chinese Coffee
#
#    video  vote_average vote_count certification
# 0    0.0           5.5       22.0           NaN
# 1    0.0           4.4        7.0           NaN
# 2    0.0           0.0        0.0           NaN
# 3    0.0           8.1     1891.0            PG
# 4    0.0           6.9       46.0             R
#
# [5 rows x 26 columns]

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3395 entries, 0 to 3394
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                3395 non-null   object
#  1   adult                  3395 non-null   float64
#  2   backdrop_path          1488 non-null   object
#  3   belongs_to_collection  247 non-null    object
#  4   budget                 3395 non-null   float64
#  5   genres                 3395 non-null   object
#  6   homepage               224 non-null    object
#  7   id                     3395 non-null   float64
#  8   original_language      3395 non-null   object
#  9   original_title         3395 non-null   object
#  10  overview               3318 non-null   object
#  11  popularity             3395 non-null   float64
#  12  poster_path            2906 non-null   object
#  13  production_companies   3395 non-null   object
#  14  production_countries   3395 non-null   object
#  15  release_date           3363 non-null   object
#  16  revenue                3395 non-null   float64
#  17  runtime                3339 non-null   float64
#  18  spoken_languages       3395 non-null   object
#  19  status                 3395 non-null   object
#  20  tagline                1304 non-null   object
#  21  title                  3395 non-null   object
#  22  video                  3395 non-null   float64
#  23  vote_average           3395 non-null   float64
#  24  vote_count             3395 non-null   float64
#  25  certification          1101 non-null   object
# dtypes: float64(9), object(17)
# memory usage: 689.7+ KB

# %%
tmdb_df = tmdb_df.drop(columns = ['adult', 'backdrop_path','belongs_to_collection',
                               'genres', 'homepage', 'id', 'original_language', 
                              'original_title', 'overview', 'popularity', 
                              'poster_path', 'production_companies',
                               'production_countries', 'release_date', 
                              'runtime', 'spoken_languages', 'status', 
                              'tagline', 'title', 'video', 'vote_average', 
                              'vote_count'])
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3395 entries, 0 to 3394
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_id        3395 non-null   object
#  1   budget         3395 non-null   float64
#  2   revenue        3395 non-null   float64
#  3   certification  1101 non-null   object
# dtypes: float64(2), object(2)
# memory usage: 106.2+ KB

# %%
# Calculate max string lengths for object columns ('tconst' and 'primaryTitle')
imdb_id_len = tmdb_df['imdb_id'].fillna('').map(len).max()

certification_len = tmdb_df['certification'].fillna('').map(len).max()



# Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    'imdb_id': String(imdb_id_len+1), 
    'budget':Float(), 
    'revenue':Float(),
    'certification': String(certification_len+1)}

# %%
tmdb_df.to_sql('tmdb_data', engine, dtype=df_schema, 
              if_exists='replace', index=False)

# %%
# Use the sqlalchemy engine to update the table and set imdb_id as the primary key
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %% [markdown]
# ## SQL Table and Rows

# %%
# Run show tables query
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3    title_ratings
# 4        tmdb_data

# %%
#genres
q = """
SELECT * 
FROM genres LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2

# %%
q = """
SELECT * 
FROM title_basics LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
#
#    runtimeMinutes
# 0             118
# 1              70
# 2             122

# %%
q = """
SELECT * 
FROM title_genres LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18

# %%
q = """
SELECT * 
FROM title_ratings LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1888
# 1  tt0000002            5.9       251
# 2  tt0000003            6.5      1680

# %%
q = """
SELECT * 
FROM tmdb_data LIMIT 3
;"""
pd.read_sql(q, engine)
# Out:
#      imdb_id      budget     revenue certification
# 0  tt0035423  48000000.0  76019000.0         PG-13
# 1  tt0113026  10000000.0         0.0          None
# 2  tt0113092         0.0         0.0          None
